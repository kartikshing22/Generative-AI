# %%
from langchain_community.tools import DuckDuckGoSearchRun
search_tool = DuckDuckGoSearchRun()
result = search_tool.invoke("what is langchain")
print(result)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/Desktop/Generative-AI/venv/lib/python3.10/site-packages/langchain_community/utilities/duckduckgo_search.py:49, in DuckDuckGoSearchAPIWrapper.validate_environment(cls, values)
#      48 try:
# ---> 49     from ddgs import DDGS  # noqa: F401
#      50 except ImportError:
#
# ModuleNotFoundError: No module named 'ddgs'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[8], line 2
#       1 from langchain_community.tools import DuckDuckGoSearchRun
# ----> 2 search_tool = DuckDuckGoSearchRun()
#       3 result = search_tool.invoke("what is langchain")
#       4 print(result)
#
# File ~/Desktop/Generative-AI/venv/lib/python3.10/site-packages/langchain_core/tools/base.py:524, in BaseTool.__init__(self, **kwargs)
#     519     msg = (
#     520         "args_schema must be a subclass of pydantic BaseModel or "
#     521         f"a JSON schema dict. Got: {kwargs['args_schema']}."
#     522     )
#     523     raise TypeError(msg)
# --> 524 super().__init__(**kwargs)
#
# File ~/Desktop/Generative-AI/venv/lib/python3.10/site-packages/langchain_core/load/serializable.py:115, in Serializable.__init__(self, *args, **kwargs)
#     113 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     114     """"""  # noqa: D419
# --> 115     super().__init__(*args, **kwargs)
#
#     [... skipping hidden 2 frame]
#
# File ~/Desktop/Generative-AI/venv/lib/python3.10/site-packages/langchain_community/utilities/duckduckgo_search.py:51, in DuckDuckGoSearchAPIWrapper.validate_environment(cls, values)
#      49     from ddgs import DDGS  # noqa: F401
#      50 except ImportError:
# ---> 51     raise ImportError(
#      52         "Could not import ddgs python package. "
#      53         "Please install it with `pip install -U ddgs`."
#      54     )
#      55 return values
#
# ImportError: Could not import ddgs python package. Please install it with `pip install -U ddgs`.
