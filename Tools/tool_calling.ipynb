# %%
pip install -U ddgs langchain_experimental

# %%
from langchain_community.tools import tool
import os
from dotenv import load_dotenv
load_dotenv(dotenv_path="../.env")
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
from langchain_core.messages import HumanMessage
os.environ["OPENAI_API_KEY"] = OPENAI_API_KEY
from langchain_openai import ChatOpenAI

# %% [markdown]
# <h3>Tool creation </h3>

# %%
@tool
def multiply(a:int,b:int) ->int:
    """take a,b and multiply a+b"""
    return a*b

# %%
print(multiply.args)
print(multiply.description)
# Out:
# {'a': {'title': 'A', 'type': 'integer'}, 'b': {'title': 'B', 'type': 'integer'}}
# take a,b and multiply a+b

# %%
llm = ChatOpenAI()

# %% [markdown]
# <h3>Tool Binding</h3>

# %%
llm_with_tools  = llm.bind_tools([multiply])

# %% [markdown]
# <h3>tool calling </h4>

# %%
result = llm_with_tools.invoke("multiply 5 and 7")

# %% [markdown]
# <h3> Tool Excution </h3>

# %%
multiply.invoke(result.tool_calls[0])
# Out:
# ToolMessage(content='35', name='multiply', tool_call_id='call_wV4aTqVLQn5hdYJYXPaDed46')

# %%
# ========================================================================================================================================================================
# New part, creating tool calling with memory, will remeber type of messages

# %%
llm.invoke('hi')
# Out:
# AIMessage(content='Hello! How can I help you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 9, 'prompt_tokens': 8, 'total_tokens': 17, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-D2tfR1VOXB4hz2NYUqy70c6fIbZxR', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--45fbe211-05c9-4177-a710-f577089bd2fa-0', usage_metadata={'input_tokens': 8, 'output_tokens': 9, 'total_tokens': 17, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
llm_with_tools = llm.bind_tools([multiply])

# %%
llm_with_tools.invoke('Hi how are you')
# Out:
# AIMessage(content="Hello! I'm here and ready to assist you. How can I help you today?", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 19, 'prompt_tokens': 53, 'total_tokens': 72, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-D2tfoUxIvsT37o7dC0cOVLsJoE4OI', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--2a7a8521-923c-4399-be19-c5414df37e42-0', usage_metadata={'input_tokens': 53, 'output_tokens': 19, 'total_tokens': 72, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
query = HumanMessage('can you multiply 3 with 1000')
messages = [query]
messages
# Out:
# [HumanMessage(content='can you multiply 3 with 1000', additional_kwargs={}, response_metadata={})]

# %%
result = llm_with_tools.invoke(messages)

# %%
messages.append(result)

# %%
messages
# Out:
# [HumanMessage(content='can you multiply 3 with 1000', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_jmhVhTWSZEIbzBDai6Jao2x7', 'function': {'arguments': '{"a":3,"b":1000}', 'name': 'multiply'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 18, 'prompt_tokens': 58, 'total_tokens': 76, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-D2tggfaBqEypBoaGaSol2Qq0eIg50', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--f9888f29-42ff-46e4-9e14-e9af9e1a475f-0', tool_calls=[{'name': 'multiply', 'args': {'a': 3, 'b': 1000}, 'id': 'call_jmhVhTWSZEIbzBDai6Jao2x7', 'type': 'tool_call'}], usage_metadata={'input_tokens': 58, 'output_tokens': 18, 'total_tokens': 76, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]

# %%
tool_result = multiply.invoke(result.tool_calls[0])
tool_result
# Out:
# ToolMessage(content='3000', name='multiply', tool_call_id='call_jmhVhTWSZEIbzBDai6Jao2x7')

# %%
messages.append(tool_result)
messages
# Out:
# [HumanMessage(content='can you multiply 3 with 1000', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_jmhVhTWSZEIbzBDai6Jao2x7', 'function': {'arguments': '{"a":3,"b":1000}', 'name': 'multiply'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 18, 'prompt_tokens': 58, 'total_tokens': 76, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-D2tggfaBqEypBoaGaSol2Qq0eIg50', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--f9888f29-42ff-46e4-9e14-e9af9e1a475f-0', tool_calls=[{'name': 'multiply', 'args': {'a': 3, 'b': 1000}, 'id': 'call_jmhVhTWSZEIbzBDai6Jao2x7', 'type': 'tool_call'}], usage_metadata={'input_tokens': 58, 'output_tokens': 18, 'total_tokens': 76, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  ToolMessage(content='3000', name='multiply', tool_call_id='call_jmhVhTWSZEIbzBDai6Jao2x7')]

# %%
llm_with_tools.invoke(messages).content
# Out:
# 'The result of multiplying 3 with 1000 is 3000.'

# %% [markdown]
# <h3> Creating a real time currency converter </h3>

# %%
# tool create
from langchain_core.tools import InjectedToolArg
from typing import Annotated
import requests

@tool
def get_conversion_factor(base_currency: str, target_currency: str) -> float:
  """
  This function fetches the currency conversion factor between a given base currency and a target currency
  """
  url = f'https://v6.exchangerate-api.com/v6/c754eab14ffab33112e380ca/pair/{base_currency}/{target_currency}'

  response = requests.get(url)

  return response.json()

@tool
def convert(base_currency_value: int, conversion_rate: Annotated[float, InjectedToolArg]) -> float:
  """
  given a currency conversion rate this function calculates the target currency value from a given base currency value
  """

  return base_currency_value * conversion_rate

# %%
convert.args
# Out:
# {'base_currency_value': {'title': 'Base Currency Value', 'type': 'integer'},
#  'conversion_rate': {'title': 'Conversion Rate', 'type': 'number'}}

# %%
get_conversion_factor.invoke({'base_currency':'USD','target_currency':'INR'})
# Out:
# {'result': 'success',
#  'documentation': 'https://www.exchangerate-api.com/docs',
#  'terms_of_use': 'https://www.exchangerate-api.com/terms',
#  'time_last_update_unix': 1769644802,
#  'time_last_update_utc': 'Thu, 29 Jan 2026 00:00:02 +0000',
#  'time_next_update_unix': 1769731202,
#  'time_next_update_utc': 'Fri, 30 Jan 2026 00:00:02 +0000',
#  'base_code': 'USD',
#  'target_code': 'INR',
#  'conversion_rate': 92.0077}

# %%
convert.invoke({'base_currency_value':10, 'conversion_rate':85.16})
# Out:
# 851.5999999999999

# %%
# tool binding
llm = ChatOpenAI()
llm_with_tools = llm.bind_tools([get_conversion_factor, convert])
messages = [HumanMessage('What is the conversion factor between INR and USD, and based on that can you convert 10 inr to usd')]
ai_message = llm_with_tools.invoke(messages)
messages.append(ai_message)
ai_message.tool_calls
# Out:
# [{'name': 'get_conversion_factor',
#   'args': {'base_currency': 'INR', 'target_currency': 'USD'},
#   'id': 'call_jFUn1hyozhHxeEKlMPt26o4v',
#   'type': 'tool_call'},
#  {'name': 'convert',
#   'args': {'base_currency_value': 10},
#   'id': 'call_DfVZJKy3Ry7YAb5byTue6nt7',
#   'type': 'tool_call'}]

# %%
import json

for tool_call in ai_message.tool_calls:
  # execute the 1st tool and get the value of conversion rate
  if tool_call['name'] == 'get_conversion_factor':
    tool_message1 = get_conversion_factor.invoke(tool_call)
    # fetch this conversion rate
    conversion_rate = json.loads(tool_message1.content)['conversion_rate']
    # append this tool message to messages list
    messages.append(tool_message1)
  # execute the 2nd tool using the conversion rate from tool 1
  if tool_call['name'] == 'convert':
    # fetch the current arg
    tool_call['args']['conversion_rate'] = conversion_rate
    tool_message2 = convert.invoke(tool_call)
    messages.append(tool_message2)

messages
# Out:
# [HumanMessage(content='What is the conversion factor between INR and USD, and based on that can you convert 10 inr to usd', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_jFUn1hyozhHxeEKlMPt26o4v', 'function': {'arguments': '{"base_currency": "INR", "target_currency": "USD"}', 'name': 'get_conversion_factor'}, 'type': 'function'}, {'id': 'call_DfVZJKy3Ry7YAb5byTue6nt7', 'function': {'arguments': '{"base_currency_value": 10}', 'name': 'convert'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 52, 'prompt_tokens': 123, 'total_tokens': 175, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-D3ElSgsrMxwMUU3wE3RwZzEgJctPx', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--aed61bc6-c596-42c7-82a2-7a43a1cfe540-0', tool_calls=[{'name': 'get_conversion_factor', 'args': {'base_currency': 'INR', 'target_currency': 'USD'}, 'id': 'call_jFUn1hyozhHxeEKlMPt26o4v', 'type': 'tool_call'}, {'name': 'convert', 'args': {'base_currency_value': 10, 'conversion_rate': 0.01087}, 'id': 'call_DfVZJKy3Ry7YAb5byTue6nt7', 'type': 'tool_call'}], usage_metadata={'input_tokens': 123, 'output_tokens': 52, 'total_tokens': 175, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  ToolMessage(content='{"result": "success", "documentation": "https://www.exchangerate-api.com/docs", "terms_of_use": "https://www.exchangerate-api.com/terms", "time_last_update_unix": 1769644802, "time_last_update_utc": "Thu, 29 Jan 2026 00:00:02 +0000", "time_next_update_unix": 1769731202, "time_next_update_utc": "Fri, 30 Jan 2026 00:00:02 +0000", "base_code": "INR", "target_code": "USD", "conversion_rate": 0.01087}', name='get_conversion_factor', tool_call_id='call_jFUn1hyozhHxeEKlMPt26o4v'),
#  ToolMessage(content='0.10869999999999999', name='convert', tool_call_id='call_DfVZJKy3Ry7YAb5byTue6nt7')]

# %%
llm_with_tools.invoke(messages).content
# Out:
# 'The conversion factor between INR and USD is 0.01087. \n\nSo, converting 10 INR to USD gives approximately 0.1087 USD.'
